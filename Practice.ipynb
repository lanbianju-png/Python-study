# %%
#开始愉快的PYTHIN学习吧
#1.HELLO WORLD
print("Hello! BLCU")
print("这是我的第一个程序！")

# %%
#2.新建代码文件20221168001-2.ipynb，提示学生输入以下信息，然后据输入信息打印学生的名片，程序运行结果如下：


name=input("请输入你的姓名")
birthyear=float(input("出生年份"))
age=2025-birthyear

major=input("专业")
college=input("学校")


print("-------------------\n",college,major,"\n",name,age,"\n","-------------------")

# %%
# %pwd

# %%
#3.在20221168001-2.ipynb中新的单元格输入代码，提示输入以下信息，然后据输入信息计算梯形的面积，程序运行结果如下：

a=float(input("length"))
b=float(input("width"))
c=float(input("height"))


s=(a+b)*c
print(s)

# %%
#4. 在20221168001-2.ipynb中新的单元格输入代码，提示输入x, y 的值 ，然后据输入数据做加减乘除、取余，乘方等运算，程序运行结果如下：

x=float(input("变量1"))
y=float(input("变量2"))

c=x+y
k=x-y
s=x*y
q=x/y
w=x//y
e=x%y
i=x**y

print(c),print(k),print(s),print(q),print(w),print(e),print(i)
